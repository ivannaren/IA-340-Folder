# %% [markdown]
# # Lab1

# %% [markdown]
# This is my first lab.

# %%
import pandas as pd

covid_data = pd.read_csv('s3://ia.340.fall.semester.2025qwerty/data.csv')

covid_data.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
import pandas as pd

covid_data = pd.read_csv('s3://ia.340.fall.semester.2025qwerty/Retail_Food_Stores.csv')

covid_data.head()
# Out:
#      County  License Number Operation Type Establishment Type  Entity Name  \
# 0    ALBANY          750931          Store                 AC  EVANS JULIA
# 1     KINGS          619451          Store                 AC  159-MP CORP
# 2     KINGS          751355          Store                 AC    YDHNY INC
# 3  SARATOGA          722816          Store                 AC     IANS LLC
# 4   SUFFOLK          719057          Store                 AC   HO 110 INC
#
#    DBA Name Street Number Street Name Address Line 2 Address Line 3  \
# 0   TERROSA             8   VERDA AVE            NaN            NaN
# 1  FOODTOWN           159    N 3RD ST            NaN            NaN
# 2     YDHNY            25    N 5TH ST            NaN            NaN
# 3      IANS          1500        RT 9            NaN            NaN
# 4     EXXON          1350      RT 110            NaN            NaN
#
#            City State  Zip Code  Square Footage  \
# 0   CLARKSVILLE    NY     12041             NaN
# ...
